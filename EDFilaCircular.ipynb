# %%
#1 Trabalho Fila Circular Victor Trarbach Nunes
class FilaCircular:
    
    def __init__(self, max=10):
        self.first = self.size = 0 
        self.last = max + 0
        self.data = [None]*max
        self.max = max
        
    def __len__(self): 
        return len(self.size)
        # retorna quantos elementos foram inseridos. Usar o atributo size. 
        # A fila está cheia quando size fica igual à max

    def isFull(self):
        return self.size == self.max

        # A fila está cheia quando o size é 0
    def isEmpty(self):
        return self.size == 0
        
        
        # Função que adiciona um item à fila
        # Muda o last e o size
    def EnQueue(self, elem):
        if self.isFull():
            print("\nFull\n")
            return
        
        self.last = (self.last + 1) % (self.max)
        self.data[self.last] = elem
        self.size = self.size + 1
        print("% s enqueued to queue"  % str(elem))
        
        # Função para remover um item da fila
        # Mudando o first e o size
    def DeQueue(self):
        if self.isEmpty():
            print("\nEmpty\n")
            return
        
        print("% s dequeued from queue" % str(self.data[self.first]))
        self.first = (self.first + 1) % (self.max)
        self.size = self.size -1
        
        # caso a fila não esteja vazia, retorna o primeiro elemento da fila;
        # caso contrário exibir uma mensagem e depois retornar None 

    def que_first(self):
        if self.isEmpty():
            print("Queue is empty")
            return None
        print("first item is\n", self.data[self.first])    
        
    def que_last(self):
        if self.isEmpty():
            print("Queue is empty")
            return None
        print("Last item is\n",  self.data[self.last])

        # Tentativa de printar a queue, a complexidade foi aumentando e eu não consegui acompanhar a lógica com o print, 
        # Fiz o outra estrutura abaixo conseguindo printar 
        # Tentei ir atrás, procurar na web e pedir ajuda mas n rolou

    def printCQueue(self):
        if self.isEmpty():
            print("No element in the circular queue")
        elif (self.first >= self.last):
            for i in range(self.last, self.first + 1):
                print(self.data[i], end=" ")
            print()
        else:
            for i in range(self.last, self.k):
                print(self.data[i])
            for i in range(0, self.first + 1):
                print(self.data[i], end=" ")
            print()

#Criar um método fora da classe FilaCircular, no programa principal, que imprime a fila e a restaura. 
class CreateQueue(BaseException):
    if __name__ == '__main__':

        queue = FilaCircular(10)
        queue.EnQueue('jack')
        queue.EnQueue('james')
        queue.EnQueue('dylan')
        queue.EnQueue('jess')
        queue.EnQueue('gabriel')
        queue.EnQueue('saulo')
        queue.EnQueue('victor')
        queue.EnQueue('sam')
        queue.EnQueue('nathan')
        queue.EnQueue('john')
        queue.printCQueue()

        # 3) tentar inserir mais um aluno(decimo primeiro aluno da lista) na fila e informar o que acontece. 
        queue.EnQueue('Rakan') #11º Aluno, que printa FULL, pois a fila está cheia 
        queue.que_first()
        queue.que_last()
        queue.DeQueue()
        queue.que_first()
        queue.que_last()
        

        # 4) remover 3 alunos da fila e exibir a fila. 
        queue.DeQueue()
        queue.DeQueue()
        queue.DeQueue()
        queue.printCQueue()
        
        # 5) adicionar mais 3 alunos (os 3 últimos da lista) na fila e exibir a fila.
        queue.EnQueue('sam')
        queue.EnQueue('nathan')
        queue.EnQueue('john')
        #TESTE print(queue)
        
    pass
    
class Aluno:
    
    def __init__(self, nome, matricula):
        #self.nome = ['jack', 'james', 'dylan', 'jess', 'gabriel', 'saulo', 'victor', 'sam', 'nathan', 'john']
        self.nome = nome
        self.matricula = matricula
        self.notas = [None]*3
        
    def insere_notas(self, n1, n2, n3):
        self.n1 = float(input('primeira nota do aluno:'))
        self.n2 = float(input('Segunda nota do aluno:'))
        self.n3 = float(input('Terceira nota do aluno:'))
    def computa_media(self):          
        self.m = (self.n1 + self.n2 + self.n3)/2
        print('A média entre{}, {} e {} é igual a {}'.format(self.n1, self.n2, self.n3, self.m))
        
    def __str__(self):
        my_list = []
        for i in self.items[self.last:]:
            my_list.append(i)

        for i in self.items[:self.first+1]:
            my_list.append(i)

        return str(my_list)
# Out:
# jack enqueued to queue
# james enqueued to queue
# dylan enqueued to queue
# jess enqueued to queue
# gabriel enqueued to queue
# saulo enqueued to queue
# victor enqueued to queue
# sam enqueued to queue
# nathan enqueued to queue
# john enqueued to queue
# john
#
# Full
#
# first item is
#  john
# Last item is
#  john
# john dequeued from queue
# first item is
#  jack
# Last item is
#  john
# jack dequeued from queue
# james dequeued from queue
# dylan dequeued from queue
# john jack james dylan jess
# sam enqueued to queue
# nathan enqueued to queue
# john enqueued to queue
# ...

# %%
#2 Trabalho FilaCircular Victor Trarbach Nunes


class FilaCircular():

    def __init__(self, k=10):
        self.head = self.size = -1
        self.last = k + 0
        self.queue = [None] * k
        self.k = k 

    def __len__(self): 
        return len(self.size)
      # retorna quantos elementos foram inseridos. Usar o atributo size. 
      # A fila está cheia quando size fica igual à max

    def isFull(self):
        return self.size == self.k 
    # A fila está cheia quando o size é 0
    def isEmpty(self):
        return self.size == -1 
    # Função que adiciona um item à fila
    # Muda o last e o size
    def enqueue(self, elem):

        if self.isFull():
            print("Full")
            return
        
        self.last = (self.last + 1) % (self.k)
        self.queue[self.last] = elem
        self.size = self.size + 1
        print("% s enqueued to queue"  % str(elem))

    # Função para remover um item da fila
    # Mudando o first e o size
    def dequeue(self):
        if self.isEmpty():
            print("Empty")
            return
        
        print("% s dequeued from queue\n" % str(self.queue[self.head]))
        self.head = (self.head + 1) % (self.k)
        self.size = self.size -1

    # caso a fila não esteja vazia, retorna o primeiro elemento da fila;
    # caso contrário exibir uma mensagem e depois retornar None 
    def que_first(self):
            if self.isEmpty():
                print("Queue is empty")
            print("First item is:\n", self.queue[self.head])    
            
    def que_last(self):
            if self.isEmpty():
                print("Queue is empty")
            print("Last item is",  self.queue[self.last])
        

    def printCQueue(self):
        if(self.head == -2):
            print("No element in the circular queue")

        elif (self.size >= self.head):
            for i in range(self.head, self.size + 1):
                print(self.queue[i], end=" ")
            print()
        else:
            for i in range(self.head, self.k):
                print(self.queue[i], end=" ")
            for i in range(0, self.size + 1):
                print(self.queue[i], end=" ")
            print()


# Your FilaCircular object will be instantiated and called as such:
obj = FilaCircular(10)
obj.enqueue('jack')
obj.enqueue('james')
obj.enqueue('dylan')
obj.enqueue('jess')
obj.enqueue('gabriel')
obj.enqueue('saulo')
obj.enqueue('victor')
obj.enqueue('sam')
obj.enqueue('nathan')
obj.enqueue('john')
# obj.enqueue('Luiz')  # 3) tentar inserir mais um aluno(decimo primeiro aluno da lista) na fila e informar o que acontece. 
#11º Aluno, que printa FULL, pois a fila está cheia 

obj.que_first()
print("Initial queue")

obj.printCQueue()
# 4) remover 3 alunos da fila e exibir a fila.
obj.dequeue()
obj.dequeue()
obj.dequeue()
print("Depois de remover 3 alunos:")
obj.printCQueue()
# 5) adicionar mais 3 alunos (os 3 últimos da lista) na fila e exibir a fila.
obj.enqueue('sam')
obj.enqueue('nathan')
obj.enqueue('john')
print("Depois de add os 3 alunos:")
obj.printCQueue()

class Aluno:
    
    def __init__(self, nome, matricula):
        #self.nome = ['jack', 'james', 'dylan', 'jess', 'gabriel', 'saulo', 'victor', 'sam', 'nathan', 'john']
        self.nome = nome
        self.matricula = matricula
        self.notas = [None]*3
        
    def insere_notas(self, n1, n2, n3):
        self.n1 = float(input('primeira nota do aluno:'))
        self.n2 = float(input('Segunda nota do aluno:'))
        self.n3 = float(input('Terceira nota do aluno:'))
    def computa_media(self):          
        self.m = (self.n1 + self.n2 + self.n3)/2
        print('A média entre{}, {} e {} é igual a {}'.format(self.n1, self.n2, self.n3, self.m))
        
    def __str__(self):
        my_list = []
        for i in self.items[self.last:]:
            my_list.append(i)

        for i in self.items[:self.first+1]:
            my_list.append(i)

        return str(my_list)
# Out:
# jack enqueued to queue
# james enqueued to queue
# dylan enqueued to queue
# jess enqueued to queue
# gabriel enqueued to queue
# saulo enqueued to queue
# victor enqueued to queue
# sam enqueued to queue
# nathan enqueued to queue
# john enqueued to queue
# First item is:
#  nathan
# Initial queue
# nathan john jack james dylan jess gabriel saulo victor sam nathan
# nathan dequeued from queue
#
# john dequeued from queue
#
# jack dequeued from queue
#
# Depois de remover 3 alunos:
# james dylan jess gabriel saulo
# sam enqueued to queue
# nathan enqueued to queue
# john enqueued to queue
# Depois de add os 3 alunos:
# nathan john jess gabriel saulo victor sam nathan

# %%
# Out:
# jack enqueued to queue
# james enqueued to queue
# dylan enqueued to queue
# jess enqueued to queue
# gabriel enqueued to queue
# saulo enqueued to queue
# victor enqueued to queue
# sam enqueued to queue
# nathan enqueued to queue
# john enqueued to queue
# john
#
# Full
#
# first item is
#  john
# Last item is
#  john
# john dequeued from queue
# first item is
#  jack
# Last item is
#  john
# jack dequeued from queue
# james dequeued from queue
# dylan dequeued from queue
# john jack james dylan jess
# sam enqueued to queue
# nathan enqueued to queue
# john enqueued to queue
# ...

# %% [markdown]
# # Trabalho FilaCircular Victor Trarbach Nunes
# class MyCircularQueue():
#
#     def __init__(self, k):
#         self.k = k
#         self.queue = [None] * k
#         self.head = self.tail = -1
#
#     # Insert an element into the circular queue
#     def enqueue(self, data):
#
#         if ((self.tail + 1) % self.k == self.head):
#             print("The circular queue is full\n")
#
#         elif (self.head == -1):
#             self.head = 0
#             self.tail = 0
#             self.queue[self.tail] = data
#         else:
#             self.tail = (self.tail + 1) % self.k
#             self.queue[self.tail] = data
#
#     # Delete an element from the circular queue
#     def dequeue(self):
#         if (self.head == -1):
#             print("The circular queue is empty\n")
#
#         elif (self.head == self.tail):
#             temp = self.queue[self.head]
#             self.head = -1
#             self.tail = -1
#             return temp
#         else:
#             temp = self.queue[self.head]
#             self.head = (self.head + 1) % self.k
#             return temp
#
#     def printCQueue(self):
#         if(self.head == -1):
#             print("No element in the circular queue")
#
#         elif (self.tail >= self.head):
#             for i in range(self.head, self.tail + 1):
#                 print(self.queue[i], end=" ")
#             print()
#         else:
#             for i in range(self.head, self.k):
#                 print(self.queue[i], end=" ")
#             for i in range(0, self.tail + 1):
#                 print(self.queue[i], end=" ")
#             print()
#
#
# # Your MyCircularQueue object will be instantiated and called as such:
# obj = MyCircularQueue(5)
# obj.enqueue(1)
# obj.enqueue(2)
# obj.enqueue(3)
# obj.enqueue(4)
# obj.enqueue(5)
# print("Initial queue")
# obj.printCQueue()
#
# obj.dequeue()
# print("After removing an element from the queue")
# obj.printCQueue()
#
#             # 3) tentar inserir mais um aluno(decimo primeiro aluno da lista) na fila e informar o que acontece.
#             obj.EnQueue('Rakan') #11º Aluno, que printa FULL, pois a fila está cheia
#             obj.que_first()
#             obj.que_last()
#             obj.DeQueue()
#             obj.que_first()
#             obj.que_last()
#             # 4) remover 3 alunos da fila e exibir a fila.
#             obj.DeQueue()
#             obj.DeQueue()
#             obj.DeQueue()
#             obj.printQ()
#             # 5) adicionar mais 3 alunos (os 3 últimos da lista) na fila e exibir a fila.
#             obj.EnQueue('Andre')
#             obj.EnQueue('RATO')
#             obj.EnQueue('GORDO')
#             obj.printQ()
#
#
#
# class Aluno:
#
#     def __init__(self, nome, matricula):
#         #self.nome = ['jack', 'james', 'dylan', 'jess', 'gabriel', 'saulo', 'victor', 'sam', 'nathan', 'john']
#         self.nome = nome
#         self.matricula = matricula
#         self.notas = [None]*3
#
#     def insere_notas(self, n1, n2, n3):
#         self.n1 = float(input('primeira nota do aluno:'))
#         self.n2 = float(input('Segunda nota do aluno:'))
#         self.n3 = float(input('Terceira nota do aluno:'))
#     def computa_media(self):
#         self.m = (self.n1 + self.n2 + self.n3)/2
#         print('A média entre{}, {} e {} é igual a {}'.format(self.n1, self.n2, self.n3, self.m))
#
#     def __str__(self):
#         my_list = []
#         for i in self.items[self.last:]:
#             my_list.append(i)
#
#         for i in self.items[:self.first+1]:
#             my_list.append(i)
#
#         return str(my_list)
